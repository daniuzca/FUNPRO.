# %% [markdown]
# <a href="https://colab.research.google.com/github/daniuzca/FUNPRO./blob/main/Clase_1_IF_ELSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Estructuras de repeticion

# %% [markdown]
# ##Estructura if/else
# Son estructuras que evaluan una condicion. Da un resultado booleando
#
# (True o Falso).
#
#
# Sintaxis de si/sino
# ```
# if condicion:
#  codigo a ejeccutar si la condicion es verdadera
# else:
#  codigo a ejecutas si la condicion es falsa
# ```

# %% [markdown]
# # Nueva sección
